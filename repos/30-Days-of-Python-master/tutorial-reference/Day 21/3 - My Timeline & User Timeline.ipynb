# %%
# !pip install pandas

# %%
import tweepy
import webbrowser
import time
import pandas as pd

# %%
consumer_key = "82sYf9hQSpGNuc9K8wTVGOqz0"
consumer_secret = "6tf3Iu3eiaLesTA2yxZPD2Ht7cJxs4Nk8vxBH0ltAPD3enaNGK"
callback_uri = 'oob'
auth = tweepy.OAuthHandler(consumer_key, consumer_secret, callback_uri)
redirect_url = auth.get_authorization_url()
webbrowser.open(redirect_url)
user_pint_input = input("What's the pin value? ")
auth.get_access_token(user_pint_input)
# Out:
# What's the pin value? 7194166
# ('4730574793-fa9oFomAHt4K4iw5uaWRaG0iw1OxCUu47ieHm5Q',
#  'fOC4HAcXzr35dl8gZdzZdkC0dBr7l26pOvJv56oqF4yTf')

# %%
api = tweepy.API(auth)

# %%
me = api.me()
me.screen_name
# Out:
# 'joincfe'

# %%
my_timeline = api.home_timeline()
# print(my_timline)

# %%
columns = set()
allowed_types = [str, int]
tweets_data = []
for status in my_timeline:
    print(status.author.screen_name)
    # print(type(vars(status)))
    status_dict = dict(vars(status))
    keys = status_dict.keys()
    single_tweet_data = {"user": status.user.screen_name, "author": status.author.screen_name}
    for k in keys:
        try:
            v_type = type(status_dict[k])
        except:
            v_type = None
        if v_type != None:
            if v_type in allowed_types:
                single_tweet_data[k] = status_dict[k]
                columns.add(k)
    tweets_data.append(single_tweet_data)

        
header_cols = list(columns)
header_cols.append("user")
header_cols.append('author')
# Out:
# HaithemDissem
# code
# zeitreisender_
# pycoders
# heroku
# pycoders
# pycoders
# Ajibel
# heroku
# ThePSF
# pycoders
# pycoders
# heroku
# ThePSF
# pycoders
# pycoders
# Ajibel
# code
# zeitreisender_

# %%
header_cols
# Out:
# ['favorite_count',
#  'lang',
#  'retweet_count',
#  'source_url',
#  'text',
#  'source',
#  'quoted_status_id',
#  'id_str',
#  'quoted_status_id_str',
#  'id',
#  'user',
#  'author']

# %%
tweets_data
# Out:
# [{'user': 'HaithemDissem',
#   'author': 'HaithemDissem',
#   'id': 1257771942465032194,
#   'id_str': '1257771942465032194',
#   'text': 'RT @Victoryabro: Have a great weekend!\n@Dahl_Consult @DrJDrooghaag @RagusoSergio @postoff25 @ShiCooks @CurieuxExplorer @baski_LA @Droit_IA…',
#   'source': 'Twitter for Android',
#   'source_url': 'http://twitter.com/download/android',
#   'retweet_count': 30,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'user': 'code',
#   'author': 'code',
#   'id': 1257764530882568195,
#   'id_str': '1257764530882568195',
#   'text': 'RT @mattbierner: Today\'s @code setting: debug.toolBarLocation\n\nFloating debug controls getting in the way? Just set debug.toolBarLocation:"…',
#   'source': 'Twitter Web App',
#   'source_url': 'https://mobile.twitter.com',
#   'retweet_count': 27,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'user': 'zeitreisender_',
#   'author': 'zeitreisender_',
#   'id': 1257757469864013827,
#   'id_str': '1257757469864013827',
#   'text': 'RT @BrendaMonzonGT: Amigos si pueden donar víveres por favor ,🙏🏽 son las viudas de pilotos del transporte urbano y sus hijos.',
#   'source': 'Twitter for Android',
#   'source_url': 'http://twitter.com/download/android',
#   'quoted_status_id': 1257469398555725829,
#   'quoted_status_id_str': '1257469398555725829',
#   'retweet_count': 3,
#   'favorite_count': 0,
#   'lang': 'es'},
#  {'user': 'pycoders',
#   'author': 'pycoders',
#   'id': 1257754517204021250,
#   'id_str': '1257754517204021250',
#   'text': '📰🐍Hot off the press: PyCoder’s Weekly Issue #419 (May 5, 2020) https://t.co/YFDPuxOBmH',
#   'source': 'Zapier.com',
#   'source_url': 'https://zapier.com/',
#   'retweet_count': 2,
#   'favorite_count': 4,
#   'lang': 'en'},
#  {'user': 'heroku',
#   'author': 'heroku',
#   'id': 1257742901120909312,
#   'id_str': '1257742901120909312',
#   'text': "RT @schneems: It's taken me 9+ months of work, but I've finally added rate-throttling to Heroku's `platform-api` gem. Along with some amazi…",
#   'source': 'Twitter Web App',
#   'source_url': 'https://mobile.twitter.com',
#   'retweet_count': 2,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'user': 'pycoders',
#   'author': 'pycoders',
#   'id': 1257740348631273475,
#   'id_str': '1257740348631273475',
#   'text': 'Python 3.9.0a6 Is Now Available for Testing  https://t.co/3VZzTxj5uN',
#   'source': 'Buffer',
#   'source_url': 'https://buffer.com',
#   'retweet_count': 5,
#   'favorite_count': 9,
#   'lang': 'en'},
#  {'user': 'pycoders',
#   'author': 'pycoders',
#   'id': 1257740348513759232,
#   'id_str': '1257740348513759232',
#   'text': 'PyBoy: GameBoy Emulator Written in Python  https://t.co/04Dj1RKVJD',
#   'source': 'Buffer',
#   'source_url': 'https://buffer.com',
#   'retweet_count': 3,
#   'favorite_count': 10,
#   'lang': 'en'},
#  {'user': 'Ajibel',
#   'author': 'Ajibel',
#   'id': 1257737534794326016,
#   'id_str': '1257737534794326016',
#   'text': 'RT @LSMOH: #COVID19Lagos Update\nBreaking! \n*️⃣60 more #COVID19Lagos patients; 20 females &amp; 40 males, all Nigerians were today discharged fr…',
#   'source': 'Twitter Web App',
#   'source_url': 'https://mobile.twitter.com',
#   'retweet_count': 289,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'user': 'heroku',
#   'author': 'heroku',
#   'id': 1257731916092112905,
#   'id_str': '1257731916092112905',
#   'text': 'New on Code[ish] -  #HTML &amp; #CSS &amp; #JavaScript, oh my! Wrangling these languages to craft performant websites can b… https://t.co/XAqSoRImyE',
#   'source': 'Salesforce - Social Studio',
#   'source_url': 'http://www.salesforce.com',
#   'retweet_count': 0,
#   'favorite_count': 3,
#   'lang': 'en'},
#  {'user': 'ThePSF',
#   'author': 'ThePSF',
#   'id': 1257703608360955905,
#   'id_str': '1257703608360955905',
#   'text': 'The official Python Developers Survey 2019 results are here! https://t.co/f9kEso4Df8 #pythondevsurvey',
#   'source': 'Sprout Social',
#   'source_url': 'https://sproutsocial.com',
#   'retweet_count': 36,
#   'favorite_count': 89,
#   'lang': 'en'},
#  {'user': 'pycoders',
#   'author': 'pycoders',
#   'id': 1257703116860018689,
#   'id_str': '1257703116860018689',
#   'text': 'alembic_utils: Sqlalchemy/Alembic Extension for Migrating Procedures and Views  https://t.co/hLLbIQwWcQ',
#   'source': 'Buffer',
#   'source_url': 'https://buffer.com',
#   'retweet_count': 0,
#   'favorite_count': 4,
#   'lang': 'en'},
#  {'user': 'pycoders',
#   'author': 'pycoders',
#   'id': 1257703113752023040,
#   'id_str': '1257703113752023040',
#   'text': 'Tonks: Building One (Multi-Task) Model to Rule Them All!  https://t.co/B1FLQhxwFk',
#   'source': 'Buffer',
#   'source_url': 'https://buffer.com',
#   'retweet_count': 1,
#   'favorite_count': 5,
#   'lang': 'en'},
#  {'user': 'heroku',
#   'author': 'heroku',
#   'id': 1257688318352830464,
#   'id_str': '1257688318352830464',
#   'text': 'RT @railsconf: Eight weeks ago, when we made the agonizing call to cancel RailsConf 2020, we had no idea what the future was going to look…',
#   'source': 'Twitter Web App',
#   'source_url': 'https://mobile.twitter.com',
#   'retweet_count': 209,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'user': 'ThePSF',
#   'author': 'ThePSF',
#   'id': 1257686922652246020,
#   'id_str': '1257686922652246020',
#   'text': 'Python Developers Survey 2019 Results https://t.co/HEpU1HzYxX',
#   'source': 'IFTTT',
#   'source_url': 'https://ifttt.com',
#   'retweet_count': 8,
#   'favorite_count': 40,
#   'lang': 'en'},
#  {'user': 'pycoders',
#   'author': 'pycoders',
#   'id': 1257673153578442754,
#   'id_str': '1257673153578442754',
#   'text': 'Whole-Foods-Delivery-Slot: Automation for Whole Foods and Amazon Fresh Deliveries  https://t.co/N25C8dGf97',
#   'source': 'Buffer',
#   'source_url': 'https://buffer.com',
#   'retweet_count': 1,
#   'favorite_count': 10,
#   'lang': 'en'},
#  {'user': 'pycoders',
#   'author': 'pycoders',
#   'id': 1257644214625734656,
#   'id_str': '1257644214625734656',
#   'text': 'Python Coding Interviews: Tips &amp; Best Practices  https://t.co/8reQnApOuD',
#   'source': 'Buffer',
#   'source_url': 'https://buffer.com',
#   'retweet_count': 3,
#   'favorite_count': 7,
#   'lang': 'en'},
#  {'user': 'Ajibel',
#   'author': 'Ajibel',
#   'id': 1257641415930232832,
#   'id_str': '1257641415930232832',
#   'text': 'RT @Proud_Zara: Abeg forget about #OdumejeTheLion President Nigeria and #Lagos #Bitcoin\xa0 \n\nPlease guys single tap RT to show her some love,…',
#   'source': 'Twitter Web App',
#   'source_url': 'https://mobile.twitter.com',
#   'retweet_count': 1636,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'user': 'code',
#   'author': 'code',
#   'id': 1257521460018470919,
#   'id_str': '1257521460018470919',
#   'text': 'RT @snyksec: How do you apply and remove Kubernetes resources from within @Code IDE? @shai_mendel got you covered: https://t.co/Y9hHbXSYpf…',
#   'source': 'TweetDeck',
#   'source_url': 'https://about.twitter.com/products/tweetdeck',
#   'retweet_count': 11,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'user': 'zeitreisender_',
#   'author': 'zeitreisender_',
#   'id': 1257504864692768773,
#   'id_str': '1257504864692768773',
#   'text': 'RT @GuatexAnimales: AVELLANA es una husky de un año sus dueños ya no la quieren, estamos buscandole un súper hogar🏠 que conozca de la raza…',
#   'source': 'Twitter for Android',
#   'source_url': 'http://twitter.com/download/android',
#   'retweet_count': 90,
#   'favorite_count': 0,
#   'lang': 'es'}]

# %%
df = pd.DataFrame(tweets_data, columns=header_cols)
df.head()
# Out:
#    favorite_count lang  retweet_count                           source_url  \
# 0               0   en             30  http://twitter.com/download/android
# 1               0   en             27           https://mobile.twitter.com
# 2               0   es              3  http://twitter.com/download/android
# 3               4   en              2                  https://zapier.com/
# 4               0   en              2           https://mobile.twitter.com
#
#                                                 text               source  \
# 0  RT @Victoryabro: Have a great weekend!\n@Dahl_...  Twitter for Android
# 1  RT @mattbierner: Today's @code setting: debug....      Twitter Web App
# 2  RT @BrendaMonzonGT: Amigos si pueden donar vív...  Twitter for Android
# 3  📰🐍Hot off the press: PyCoder’s Weekly Issue #4...           Zapier.com
# 4  RT @schneems: It's taken me 9+ months of work,...      Twitter Web App
#
#    quoted_status_id               id_str quoted_status_id_str  \
# 0               NaN  1257771942465032194                  NaN
# 1               NaN  1257764530882568195                  NaN
# 2      1.257469e+18  1257757469864013827  1257469398555725829
# 3               NaN  1257754517204021250                  NaN
# 4               NaN  1257742901120909312                  NaN
#
#                     id            user          author
# 0  1257771942465032194   HaithemDissem   HaithemDissem
# 1  1257764530882568195            code            code
# 2  1257757469864013827  zeitreisender_  zeitreisender_
# 3  1257754517204021250        pycoders        pycoders
# 4  1257742901120909312          heroku          heroku

# %%
def extract_timeline_as_df(timeline_list):
    columns = set()
    allowed_types = [str, int]
    tweets_data = []
    for status in timeline_list:
        status_dict = dict(vars(status))
        keys = status_dict.keys()
        single_tweet_data = {"user": status.user.screen_name, "author": status.author.screen_name}
        for k in keys:
            try:
                v_type = type(status_dict[k])
            except:
                v_type = None
            if v_type != None:
                if v_type in allowed_types:
                    single_tweet_data[k] = status_dict[k]
                    columns.add(k)
        tweets_data.append(single_tweet_data)


    header_cols = list(columns)
    header_cols.append("user")
    header_cols.append('author')
    df = pd.DataFrame(tweets_data, columns=header_cols)
    return df

# %%
my_timeline = api.home_timeline()

# %%
df2 = extract_timeline_as_df(my_timeline)
df2.head()
# Out:
#                 source lang                           source_url  \
# 0  Twitter for Android   en  http://twitter.com/download/android
# 1      Twitter Web App   en           https://mobile.twitter.com
# 2  Twitter for Android   es  http://twitter.com/download/android
# 3           Zapier.com   en                  https://zapier.com/
# 4      Twitter Web App   en           https://mobile.twitter.com
#
#    quoted_status_id  retweet_count                   id  \
# 0               NaN             30  1257771942465032194
# 1               NaN             27  1257764530882568195
# 2      1.257469e+18              3  1257757469864013827
# 3               NaN              2  1257754517204021250
# 4               NaN              2  1257742901120909312
#
#                                                 text               id_str  \
# 0  RT @Victoryabro: Have a great weekend!\n@Dahl_...  1257771942465032194
# 1  RT @mattbierner: Today's @code setting: debug....  1257764530882568195
# 2  RT @BrendaMonzonGT: Amigos si pueden donar vív...  1257757469864013827
# 3  📰🐍Hot off the press: PyCoder’s Weekly Issue #4...  1257754517204021250
# 4  RT @schneems: It's taken me 9+ months of work,...  1257742901120909312
#
#   quoted_status_id_str  favorite_count            user          author
# 0                  NaN               0   HaithemDissem   HaithemDissem
# 1                  NaN               0            code            code
# 2  1257469398555725829               0  zeitreisender_  zeitreisender_
# 3                  NaN               4        pycoders        pycoders
# 4                  NaN               0          heroku          heroku

# %%
user = api.get_user("code")
user_timeline = user.timeline()
df3 = extract_timeline_as_df(user_timeline)
df3.head()
# Out:
#             source lang                                    source_url  \
# 0  Twitter Web App   en                    https://mobile.twitter.com
# 1        TweetDeck   en  https://about.twitter.com/products/tweetdeck
# 2  Twitter Web App   en                    https://mobile.twitter.com
# 3        TweetDeck   en  https://about.twitter.com/products/tweetdeck
# 4        TweetDeck   en  https://about.twitter.com/products/tweetdeck
#
#    in_reply_to_user_id  retweet_count                   id  \
# 0                  NaN             27  1257764530882568195
# 1                  NaN             11  1257521460018470919
# 2                  NaN              4  1257339085414371333
# 3                  NaN             35  1256039675883425792
# 4                  NaN             20  1256039515514220544
#
#    in_reply_to_status_id                                               text  \
# 0                    NaN  RT @mattbierner: Today's @code setting: debug....
# 1                    NaN  RT @snyksec: How do you apply and remove Kuber...
# 2                    NaN  Are you a @code extension developer? Join our ...
# 3                    NaN  RT @terrytyli: My first post on @ThePracticalD...
# 4                    NaN  RT @jaydestro: Register a self-hosted VS Onlin...
#
#                 id_str in_reply_to_user_id_str in_reply_to_status_id_str  \
# 0  1257764530882568195                     NaN                       NaN
# 1  1257521460018470919                     NaN                       NaN
# 2  1257339085414371333                     NaN                       NaN
# 3  1256039675883425792                     NaN                       NaN
# 4  1256039515514220544                     NaN                       NaN
#
#   in_reply_to_screen_name  favorite_count  user author
# 0                     NaN               0  code   code
# 1                     NaN               0  code   code
# 2                     NaN              47  code   code
# 3                     NaN               0  code   code
# 4                     NaN               0  code   code

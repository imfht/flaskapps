# %%
import tweepy
import webbrowser
import time
import pandas as pd

# %%
consumer_key = "82sYf9hQSpGNuc9K8wTVGOqz0"
consumer_secret = "6tf3Iu3eiaLesTA2yxZPD2Ht7cJxs4Nk8vxBH0ltAPD3enaNGK"
callback_uri = 'oob'
auth = tweepy.OAuthHandler(consumer_key, consumer_secret, callback_uri)
redirect_url = auth.get_authorization_url()
webbrowser.open(redirect_url)
user_pint_input = input("What's the pin value? ")
auth.get_access_token(user_pint_input)
# Out:
# What's the pin value? 0946129
# ('4730574793-fa9oFomAHt4K4iw5uaWRaG0iw1OxCUu47ieHm5Q',
#  'fOC4HAcXzr35dl8gZdzZdkC0dBr7l26pOvJv56oqF4yTf')

# %%
api = tweepy.API(auth, wait_on_rate_limit=True)

# %%
me = api.me()
me.screen_name
# Out:
# 'joincfe'

# %%
len(api.home_timeline(count=40))
# Out:
# 38

# %%
for i, status in enumerate(tweepy.Cursor(api.home_timeline, count=50).items(50)):
    print(i, status.text)
# Out:
# 0 RT @followlasg: Covid19 Appreciation: To the corporate giants and individuals whose handsome donations in materials and finance have helped…
# 1 VS @code has grown 8 points in 2019 comparing to the 2018’s results of the #Python Developer Survey 🥳
# We want to t… https://t.co/P9vonCeMho
# 2 Be like Mike... https://t.co/mOgYqoloP7
# 3 You can now work with GitHub repos, issues and PRs within VS Code, without ever leaving the editor 👍
# @sana_ajani an… https://t.co/6FiLVfzJR4
# 4 RT @umaar: VS Code Tip 🔥 Convert your require()'s into ES Module imports by clicking the lightbulb icon and selecting 'Convert to ES6 modul…
# 5 📢 The April release of @code is out!
#
# 🆕 GitHub authentication and GitHub issues integration, semantic theming custo… https://t.co/cYzr3fXJSo
# 6 Django Bugfix Release: 3.0.6  https://t.co/VN4FbueY8v
# 7 On the Life Blog: @activeforgood launched their free activity challenge "Active Together While Apart". Learn how yo… https://t.co/WlHuY9zo2O
# 8 Core Workflow updates - Python Language Summit 2020 https://t.co/SngneELATe
# 9 RT @alba_keneth: #AlertaAlbaKeneth  ⚠ | Marcos Axel Efren Mejia Tzoy, de 03 años de edad. Desapareció el 06 de Mayo de 2020, en Sta. María,…
# 10 Ese seguro es verdaderamente ominoso, ese dinero pudo fortalecer la Salud Pública, Centros de Salud, Hospitales, Pr… https://t.co/Rq8673ntnc
# 11 Mayo:
# Batallas de Insectos, próximamente en ESPN.
# 12 RT @spreeblick: Heute zwischen 21:30 und 22:00 Uhr: Weltpremiere Pre-Release #quaraoke, euer und unser Abschlusssingen bei der #rpREMOTE @r…
# 13 Basic Windows Kernel Programming,
#
# https://t.co/yDIJtXR5Id
#
# Cc: @mojtabamostly @zodiacon
# 14 New release - Python 3.8.3rc1. This is the release candidate of the third maintenance release of Python 3.8. The Py… https://t.co/UJtPdMHLdq
# 15 Introduction to Python's `functools` Module  https://t.co/Ltqc8edGeI
# 16 Solid #5 https://t.co/M56aIWElCN
# 17 RT @KurtZierlein: Porfa compartamos!
# 18 RT @lanena_stella: A mí me hace falta ver futbol pero si esa no es prioridad en países en donde sí tienen buen futbol, no digamos acá.
#
# Sin…
# 19 Over twenty thousand developers from more than 150 countries participated to help us map out an accurate landscape… https://t.co/A9HP31i5cu
# 20 RT @carolgamazo: Y pues al final armé la nota. Aquí se la comparto.
#
# https://t.co/MxsgFTRa3i
# 21 Generic Functions With Python's Singledispatch  https://t.co/LHSlm7hTNI
# 22 Caching in Django  https://t.co/ybsaRKCD5a
# 23 RT @BamaiyiDanladi: If U Like This This Painting, Help Me Retweet
# #Please #SaySafe #CoronaVirusIsReal.
# #CBN #Ncdc #Covid19 #Stayathome. ht…
# 24 RT @thecableindex: INFOGRAPHICS: How long can the #coronavirus live on surfaces?
#
# #COVID19 #coronavirus #StayHome #TheCableIndex https://t…
# 25 Tigruschenko... https://t.co/Nsu6renhmE
# 26 El agua que puse para el té... 🔥 https://t.co/bkdH1Vci6w
# 27 El Italiano #LordPajas ha de estar ahorita tomando un baño rejuvenecedor al estilo Cleópatra. https://t.co/2SErIxGXbn
# 28 RT @siemprevenancia: Lo siento pero la iglesia y el fútbol no son prioridad.
# 29 Me dormí y no ví la cadena, me perdí de algo bueno?
# 30 New blog post: GitHub Issues integration into VS Code!! https://t.co/YK5ZT859fG
# 31 RT @burkeholland: Thanks to @github for having us at #GitHubSatellite. It was a blast!
#
# Here's everything you need to use all the latest an…
# 32 check out @sana_ajani and @burkeholland talking about VS Code and GitHub right now https://t.co/Q1ceNXlEh6
# 33 Our team is also in Discord! Let's talk about #Python 🐍 on @Azure and VS @code.
#
# 🔗 Join us there:… https://t.co/jnITcS9oHi
# 34 The Last Dance...
# A trip down memory lane. https://t.co/KWNxzAoUPA
# 35 RT @NCDCgov: 195 new cases of #COVID19;
#
# 82-Lagos
# 30-Kano
# 19-Zamfara
# 18-Sokoto
# 10-Borno
# 9-FCT
# 8-Oyo
# 5-Kebbi
# 5-Gombe
# 4-Ogun
# 3-Katsina
# 1-Kadu…
# 36 RT @alterlego502: Recomendado, si tiene problemas de alergias, una excelente especialista en línea a buen precio!
# 37 RT @jarchomano: Amigos míos, hoy vengo a pedirles un poco de apoyo, mi esposa está dando consultas online, para que puedan hacer favor de c…
# 38 Check out the Python Developers Survey 2019 Results https://t.co/f9kEsnN2nA #pythondevsurvey
# 39 Are you interested in running for the PSF board? Nominations open May 6th: https://t.co/RJo8SEAmRH.
# 40 What are y'all doing today? I'm watching (again ♥) the awesome talk from the one and only @kimadeline_m about biase… https://t.co/0N12r3pMQv
# 41 The Hitchhiker's Guide to CLIs in Python  https://t.co/wRDxvoA9Ez
# 42 RT @burkeholland: Github is an essential part of your development workflow. But it's a separate loop from the development you do in your ed…
# 43 Mirá @rudyaldana no solo en Teculutan tendrán chance los bailarines... https://t.co/8EiZYK9vCN
# 44 I will install wordpress, codecanyon, php script or any cms  on your hosting just for $5 on fiverr
# #script #install… https://t.co/EPME0uXvG3
# 45 RT @op_tions: The Making of an Action Governor
# https://t.co/XSYcMwtEnu
# 46 Cuando Ñeto y hasta El Pirulo hablan con más sensatez que las autoridades de Gobierno, es porque ya todo valió vértebra.
# 47 Haven't downloaded it, will never download it. #ArogyaSetuApp
# Aarogya Setu: The story of a failure by @fs0c131y https://t.co/quPfnmuoSh
# 48 Éstos señores tendrán montón de trabajo en Teculután... https://t.co/H8FzIrxBnL
# 49 Poco se puede hacer contra la, ni sé como llamarla, ignorancia y negligencia talvez, de la gente, que multitudinari… https://t.co/XJAXfTekXS

# %%
other_user = "therock"
for i, status in enumerate(tweepy.Cursor(api.user_timeline, screen_name=other_user).items(20)):
    print(i, status.text)
# Out:
# 0 I‘ll ride with you, Carol 😉👊🏾❤️ https://t.co/tevJCWmcAY
# 1 Awww I love seeing this. Her reaction is just beautiful. Things like this are the best part of fame. Congratulation… https://t.co/jf5SzqHN8b
# 2 Just shoutin’ at the 😈👊🏾 https://t.co/l2usw4GL7R
# 3 RT @foodandwine: Yes, @TheRock eats cookies, and yes, they pair with tequila. https://t.co/7V8Zojk0lR
# 4 This one I enjoyed.  Thanks Ray @islewine for laughs and good mana all around. Pleasure to talk @Teremana w/ you.… https://t.co/Pl5pRihpOo
# 5 @DashaKuret is a bad ass and was a relentless competitor. The wrestling world will be very proud of her performance… https://t.co/AYe69Iw4lX
# 6 RT @foodandwine: In early February our Executive Wine Editor @IsleWine sat down with @TheRock to talk tequila, food and family. Watch the f…
# 7 @Teremana tequila and...well, everything
# 🤣🥃
# A great sit down with Exec Wine Editor @islewine. We ate, we drank, we… https://t.co/uTSvLADpPQ
# 8 Good to talk @Teremana with my buddy Ray @islewine - the executive wine editor of @foodandwine. The ‘mana was flooo… https://t.co/flXGj8gmwA
# 9 RT @SpecialOlympics: We cannot wait to watch Global Ambassador @hannahteter compete on the new season of @nbctitangames! The world of Speci…
# 10 RT @SevenBucksProd: The @NBCTitanGames competition is about to level up! Get ready to see how these Olympic, @NFL and @UFC legends perform…
# 11 We’re bringing sports back w/ the best pro-athletes on the planet for our new season of @NBCTitanGames!
# My TITAN PR… https://t.co/K7i2TWLsES
# 12 @azarilaw @Teremana Yes ma’am it’s both. I know you have good taste and standards Sara so you’ll for sure enjoy the ‘mana
# Salud’ 😉🥃
# 13 Wow props for going cold turkey. This is a big deal and hope you enjoy your @Teremana.
# Salud, my friend 🥃 https://t.co/TzpT4HVjZ1
# 14 @CWilliamson44 well it was a joke but didn’t quite land the way I expected 😂🤦🏽‍♂️
# 15 Thank you, Vince!
# Our bond will always always be special &amp; invaluable. Cheers to earning every opportunity, commit… https://t.co/8M8jXorBhv
# 16 Good choice! Thanks for the @teremana birthday shout. 🥃 https://t.co/OuOWz9iLuq
# 17 Defining times in our career. Appreciate you, brother. You’re a legend and inspiration.
# #nod ✊🏾 https://t.co/yijsIY83V2
# 18 @BillieKayWWE Appreciate this, BK. One of my favs. Stay healthy and safe. Keep kickin ass!!
# 19 Thanks to the Golden voice of our @nbctitangames for the birthday love. 👊🏾🥃 https://t.co/A84O86tBAG

# %%
the_rock_user = api.get_user(other_user)
# dir(the_rock_user)

# %%
the_rocks_friends = []
for i, _id in enumerate(tweepy.Cursor(api.friends_ids, screen_name=other_user).items(30)):
    print(i, _id)
    the_rocks_friends.append(_id)
# Out:
# 0 1024336429198049280
# 1 11347122
# 2 38349184
# 3 22799750
# 4 800707492346925056
# 5 46966542
# 6 270494532
# 7 34713362
# 8 420654392
# 9 1198582129
# 10 1075768574445305856
# 11 15876379
# 12 269647679
# 13 760543726888333312
# 14 27676444
# 15 1062738433716686848
# 16 6446742
# 17 289256940
# 18 61903300
# 19 2473821354
# 20 95023423
# 21 223841564
# 22 66573775
# 23 725897344357519360
# 24 18237511
# 25 1151204704493264897
# 26 210916633
# 27 35733687
# 28 394976672
# 29 242960383

# %%
# api.get_user(the_rocks_friends[0]).screen_name

# %%
query = "#django -jQuery -@udemy_es -Bootstrap -Discount"
for i, status in enumerate(tweepy.Cursor(api.search, q=query).items(50)):
    print(i, status.text, status.author.screen_name)
# Out:
# 0 Lot of tech-driven entrepreneurs asked us which framework should they go for – #Django or #Laravel.
#
# For that we pr… https://t.co/J1GzV8iNYh TechticSolution
# 1 RT @calvinhp: Excellent write up by @arocks about the new async features available in #Django 3.0 and what is coming up https://t.co/GR9fYr… abosio
# 2 You can put almost anything almost anywhere in #Django; as long as your routes are right.  This makes Django quite… https://t.co/CoAwxn1NHE h4ckfu
# 3 RT @eduecosystem1: Create high-quality projects for a chance to get funded by us. 1 MILLION DOLLAR will be distributed between all develope… Calcaware
# 4 RT @eduecosystem1: Create high-quality projects for a chance to get funded by us. 1 MILLION DOLLAR will be distributed between all develope… AaronCuddeback
# 5 RT @FreeDiscount45: Master Laravel PHP with basic to advance project: Jobportal -&gt; https://t.co/Fsqab1knbw
#
# #udemy #coupons #webdevelopment… AaronCuddeback
# 6 RT @eduecosystem1: Create high-quality projects for a chance to get funded by us. 1 MILLION DOLLAR will be distributed between all develope… codedailybot
# 7 RT @eduecosystem1: Create high-quality projects for a chance to get funded by us. 1 MILLION DOLLAR will be distributed between all develope… codedailybot
# 8 RT @eduecosystem1: Create high-quality projects for a chance to get funded by us. 1 MILLION DOLLAR will be distributed between all develope… codedailybot
# 9 RT @eduecosystem1: Create high-quality projects for a chance to get funded by us. 1 MILLION DOLLAR will be distributed between all develope… xaelbot
# 10 RT @eduecosystem1: Create high-quality projects for a chance to get funded by us. 1 MILLION DOLLAR will be distributed between all develope… redianbot
# 11 Create high-quality projects for a chance to get funded by us. 1 MILLION DOLLAR will be distributed between all dev… https://t.co/u4gjz2hcqN eduecosystem1
# 12 RT @FreeDiscount45: Master Laravel PHP with basic to advance project: Jobportal -&gt; https://t.co/Fsqab1knbw
#
# #udemy #coupons #webdevelopment… php_synopsis
# 13 RT @FreeDiscount45: Master Laravel PHP with basic to advance project: Jobportal -&gt; https://t.co/Fsqab1knbw
#
# #udemy #coupons #webdevelopment… Taieb_Bot
# 14 RT @FreeDiscount45: Master Laravel PHP with basic to advance project: Jobportal -&gt; https://t.co/Fsqab1knbw
#
# #udemy #coupons #webdevelopment… redianbot
# 15 RT @FreeDiscount45: Master Laravel PHP with basic to advance project: Jobportal -&gt; https://t.co/Fsqab1knbw
#
# #udemy #coupons #webdevelopment… xaelbot
# 16 RT @FreeDiscount45: Master Laravel PHP with basic to advance project: Jobportal -&gt; https://t.co/Fsqab1knbw
#
# #udemy #coupons #webdevelopment… TCrossmd
# 17 Master Laravel PHP with basic to advance project: Jobportal -&gt; https://t.co/Fsqab1knbw
#
# #udemy #coupons… https://t.co/M2XFjLAiYs FreeDiscount45
# 18 RT @geoandymcd: #100DaysOfCode Day 8-10
# -Finally cracked the while loops in my #python code for adjusting values on a plot
# -Started going o… codedailybot
# 19 RT @geoandymcd: #100DaysOfCode Day 8-10
# -Finally cracked the while loops in my #python code for adjusting values on a plot
# -Started going o… html_css_bot
# 20 Rien n'est gratuit même la violence est une prestation. Gava t'as du mal à parler mais l'ivresse t'assiste, je fais… https://t.co/WmClUFqjpY RapLines7
# 21 RT @geoandymcd: #100DaysOfCode Day 8-10
# -Finally cracked the while loops in my #python code for adjusting values on a plot
# -Started going o… redianbot
# 22 RT @geoandymcd: #100DaysOfCode Day 8-10
# -Finally cracked the while loops in my #python code for adjusting values on a plot
# -Started going o… xaelbot
# 23 RT @geoandymcd: #100DaysOfCode Day 8-10
# -Finally cracked the while loops in my #python code for adjusting values on a plot
# -Started going o… 100xcode
# 24 #100DaysOfCode Day 8-10
# -Finally cracked the while loops in my #python code for adjusting values on a plot
# -Started… https://t.co/SVuwyBnHqb geoandymcd
# 25 RT @realtoughcandy: If you're a programmer wanting to learn Python, there's a course bundle made just for you. Today's review show you ever… Taieb_Bot
# 26 RT @realtoughcandy: If you're a programmer wanting to learn Python, there's a course bundle made just for you. Today's review show you ever… redianbot
# 27 RT @realtoughcandy: If you're a programmer wanting to learn Python, there's a course bundle made just for you. Today's review show you ever… xaelbot
# 28 RT @realtoughcandy: If you're a programmer wanting to learn Python, there's a course bundle made just for you. Today's review show you ever… vishn_u99
# 29 RT @realtoughcandy: If you're a programmer wanting to learn Python, there's a course bundle made just for you. Today's review show you ever… realtoughcandy
# 30 RT @openWISP: The accepted projects of #GoogleSummerOfCode 2020 have been officially announced!
#
# Give a very warm welcome to our new contri… ManjurulHoque7
# 31 RT @PythonWeekly: Creating Interactive Views in Django via @HackersSlackers https://t.co/qVOhpv5aZU #Python #Django https://t.co/sfL2KBWwdr simonjulien
# 32 RT @ChijiokeGodwin_: Day 28, #100DaysofCode
#
# Still on password reset. I was able to implement the reset email and link.
#
# But after clicking… ManjurulHoque7
# 33 Imma just watch #Django again, I'm stressed and nothing seems to be fun right now. SaveYoShit
# 34 samuel l jackson on #Django is a trip 🤦🏾‍♂️🤦🏾‍♂️🤦🏾‍♂️ cv3killer
# 35 RT @MattAlhonte: RT HackersSlackers "RT PythonWeekly: Creating Interactive Views in Django via HackersSlackers https://t.co/jW2XXCee3u #Pyt… ManjurulHoque7
# 36 RT @ygalila: @UASGTech It seems that the Universal Acceptance Graduation project #FCIS #Ain_Shams_Uni 2020 growing fast near the end with s… vishn_u99
# 37 RT @boyanpro: #Caching in #Django from @TestDrivenio https://t.co/DevxDNe0vj MikeHerman
# 38 RT @ygalila: @UASGTech It seems that the Universal Acceptance Graduation project #FCIS #Ain_Shams_Uni 2020 growing fast near the end with s… ManjurulHoque7
# 39 RT @PythonWeekly: Creating Interactive Views in Django via @HackersSlackers https://t.co/qVOhpv5aZU #Python #Django https://t.co/sfL2KBWwdr ManjurulHoque7
# 40 RT @realjoselara: Amazing results! So I just migrated  @santuariomusic app from Django/React to https://t.co/uskvPt9elY core Razor Pages/Re… ManjurulHoque7
# 41 RT @coupon_course: React - The Complete Guide (incl Hooks, React Router, Redux) -&gt; https://t.co/meYAAwsAjC
#
# #Eduonix #webdevelopment #JavaS… Taieb_Bot
# 42 RT @coupon_course: React - The Complete Guide (incl Hooks, React Router, Redux) -&gt; https://t.co/meYAAwsAjC
#
# #Eduonix #webdevelopment #JavaS… ProjectLearn_io
# 43 RT @PythonWeekly: Creating Interactive Views in Django via @HackersSlackers https://t.co/qVOhpv5aZU #Python #Django https://t.co/sfL2KBWwdr cybe_rpunkfixer
# 44 RT @PythonWeekly: Creating Interactive Views in Django via @HackersSlackers https://t.co/qVOhpv5aZU #Python #Django https://t.co/sfL2KBWwdr vishn_u99
# 45 RT @PythonWeekly: Creating Interactive Views in Django via @HackersSlackers https://t.co/qVOhpv5aZU #Python #Django https://t.co/sfL2KBWwdr wecbxxx
# 46 RT @PythonWeekly: GraphQL Tutorial with Django (Python) and Excel - Code from Scratch https://t.co/XkTLR1Ur0C #Python #Django #GraphQL #Exc… ManjurulHoque7
# 47 @LuizSantosMusic i NEVER get that impression from #JohnnySmith #GeorgeBarnes #BiréliLagrène #PatMetheny #Django -pe… https://t.co/EzSGmv4aN8 KGinkist
# 48 RT @PythonWeekly: GraphQL Tutorial with Django (Python) and Excel - Code from Scratch https://t.co/XkTLR1Ur0C #Python #Django #GraphQL #Exc… wecbxxx
# 49 RT @realjoselara: Amazing results! So I just migrated  @santuariomusic app from Django/React to https://t.co/uskvPt9elY core Razor Pages/Re… guiChervet

# %%
query_username = "Django"
search_results = set()
for i, user in enumerate(tweepy.Cursor(api.search_users, q=query_username).items(50)):
    print(i, user.screen_name)
    search_results.add(user.screen_name)
    
print(list(search_results))
# Out:
# 0 django
# 1 djangoproject
# 2 thedjangos
# 3 djangogirls
# 4 DjangoWexler
# 5 DjangoConEurope
# 6 django_paris
# 7 DjangoDSM
# 8 DjangoGirlsPDX
# 9 djangolinks
# 10 WonderBoySolek
# 11 BillDjango3
# 12 DjangoGirlsPyUK
# 13 DjangoGirlsBCN
# 14 djangogirlsblin
# 15 DjangoConAU
# 16 Django_gocrazy
# 17 DjangoTarantino
# 18 DjangoBrands
# 19 tangowithdjango
# 20 django
# 21 djangoproject
# 22 thedjangos
# 23 djangogirls
# 24 DjangoWexler
# 25 DjangoConEurope
# 26 django_paris
# 27 DjangoDSM
# 28 DjangoGirlsPDX
# 29 djangolinks
# 30 WonderBoySolek
# 31 BillDjango3
# 32 DjangoGirlsPyUK
# 33 DjangoGirlsBCN
# 34 djangogirlsblin
# 35 DjangoConAU
# 36 Django_gocrazy
# 37 DjangoTarantino
# 38 DjangoBrands
# 39 tangowithdjango
# 40 djangogirlsshef
# 41 DjangoGirlsBLR
# 42 DjangoTricks
# 43 djangojazzfest
# 44 DjangoCoffee
# 45 DjangoGirlsSD
# 46 djangobates
# 47 thatchickcool
# 48 yngvildr
# 49 keyblademxster
# ['djangogirlsshef', 'djangobates', 'thatchickcool', 'django_paris', 'Django_gocrazy', 'DjangoCoffee', 'DjangoTarantino', 'DjangoDSM', 'DjangoWexler', 'DjangoGirlsPyUK', 'DjangoBrands', 'DjangoConAU', 'thedjangos', 'djangogirlsblin', 'djangolinks', 'DjangoGirlsSD', 'DjangoGirlsPDX', 'djangojazzfest', 'DjangoGirlsBCN', 'djangogirls', 'keyblademxster', 'django', 'DjangoTricks', 'djangoproject', 'tangowithdjango', 'yngvildr', 'DjangoConEurope', 'BillDjango3', 'WonderBoySolek', 'DjangoGirlsBLR']

# %%
query_username = "TheRock"

def process_page(page_results):
    for i, user in enumerate(page_results):
        print(i, user.screen_name)

for i, page in enumerate(tweepy.Cursor(api.search_users, q=query_username, per_page=10).pages(3)):
    print(i, "page")
    process_page(page)
# Out:
# 0 page
# 0 TheRock
# 1 1059therock
# 2 LydenCooper
# 3 957therock
# 4 973therock
# 5 therock0829
# 6 941therock
# 7 therockbest9
# 8 am1260therock
# 9 HeIsCooking
# 10 therock_wall
# 11 JimmyTraina
# 12 Therock926
# 13 933THEROCK
# 14 SaucyFaust
# 15 695THEROCK_COM
# 16 mattdavella
# 17 theROCKDINERZA
# 18 therock2701
# 19 nbctitangames
# 1 page
# 0 TheRock
# 1 1059therock
# 2 LydenCooper
# 3 957therock
# 4 973therock
# 5 therock0829
# 6 941therock
# 7 therockbest9
# 8 am1260therock
# 9 HeIsCooking
# 10 therock_wall
# 11 JimmyTraina
# 12 Therock926
# 13 933THEROCK
# 14 SaucyFaust
# 15 695THEROCK_COM
# 16 mattdavella
# 17 theROCKDINERZA
# 18 therock2701
# 19 nbctitangames
# 2 page
# 0 hardik_therock
# 1 RestartTherock
# 2 DlCKtifying
# 3 therock_lover98
# 4 CarnelianDQ
# 5 AJKirsch
# 6 therock14
# 7 spicer2therock
# 8 Gaurav_TheRock
# 9 GRT_TheRock
# 10 JoshRimerPR
# 11 athleticonatl
# 12 SevenBucksProd
# 13 UniqueWorkEthic
# 14 The_Johnson55
# 15 EthanLind
# 16 therock1982
# 17 tarak_santhosh9
# 18 therock_2024
# 3 page
# 0 _omargHonim
# 1 JoeVFox12
# 2 ZachKrantz
# 3 therock676
# 4 ID_BeenTaken
# 5 therock73773883
# 6 therock454
# 7 ProjectRock
# 8 kevin_therock
# 9 pera_therock
# 10 THEROCK37756708
# 11 therock9002000
# 12 therock108
# 13 MyTherock3
# 14 therock6000
# 15 therock785
# 16 bigjay9inches
# 17 therock2086
# 18 TheRockBryer
# 19 therock1424

# %%
import time

def limit_handled(cursor):
    while True:
        try:
            yield cursor.next()
        except tweepy.RateLimitError:
            # send email / webhook / log
            time.sleep(15 * 60) # 15 minutes = 15 * 60 seconds

# %%
for follower in limit_handled(tweepy.Cursor(api.followers).items()):
    print(follower.screen_name)
# Out:
# DanielR29599473
# rayomahony
# cesarunt
# Happy_Code_Py
# surdy_a
# jamorap
# BlackMovieGuess
# DeepDiveEd1
# GTWeb_uk
# sub7ata
# jahid_ictian
# AppleStarn
# delavegaomar
# AfenikhenaF
# ZyyJae
# mauchi22
# cullinap
# TonyDaso
# TorshakMozyora
# Dean23310573
# AdrianTapiaSilv
# mr_k1n1
# clairvoy_Ant
# dbukhari_
# antunes73
# tystarcz
# i_May_sam
# shnekels
# netamsandeep
# FreedomFramewrc
# __shreyansh___
# vasu_vasuvirat
# chika_gladys
# waleh_jones
# iamndeleva
# officiialPrazol
# Mohamed27072339
# mlsandreas
# bernardobap84
# fred_sanchez93
# Gios_Osorio
# Mok49393340
# melwyntee
# omoba_exclusive
# DJ_Dani_Serbia
# GetSmartMachine
# AbundanceLove1
# antoniogarcia78
# tofunmi_boy
# sergeyltvn
# bk_codes
# arjun_kayal
# Niteshs18452210
# OsmanArtuner
# 4xoMil
# MarkWalshIrl
# tightai
# BoBarabas
# victorgbonnaAFC
# WxClariNerd
# truthyTester
# gnepoahs
# senor_jefferson
# JDipakSen
# alphageeks_
# mariosanchezcc
# shriramyadav1
# abrahamdmt1
# heepie1
# sunwarul
# jwicka11
# jackfusion
# SaadPastaDev
# rads39845
# DJRGit
# _MESpace_
# jackpot75093140
# CicekAyhan
# zigorzag
# seba_saade
# Mohammedik2005
# rje4242
# UmarAAHameed0
# Med_farih
# Milan_Gerovac
# sunmbie
# iam_MrFox
# BrooseNM
# CzarFelix
# meckillani
# Yeahboilerplate
# TodSira
# krishnasagar1
# __areebkhan__
# CurtisThomasIII
# DaphneGaspard1
# mohantsm
# CodepathKarla
# toby2bee
# raddron
# matics2008
# crlsmelegrito
# Sarmlu
# joannajarmusz
# n8ebel
# zorojurio
# fermiummedia
# man_as_code
# BettyHan13
# gereltod
# WindowsDocs
# edipretoro
# rmiyazaki3
# AkshayS65378592
# sol14026084
# StatsWay
# Hasanzadeh99
# matthew02
# SunilkumarValm1
# PragyanPrakash3
# Rk__Rafi
# luumelo14
# pythonvscode
# blalyasar
# Sushil_choco
# ezzaitounim
# jmfullstack
# xarala221
# Tom95854085
# I67730149
# eng_jimmie
# AhmedTHatata
# Valuware
# missgarg
# JoelDeteves
# monwer_tareq
# ZakAiDev
# Mittalistic
# CraftsCoder
# umdadev
# son_chetan
# roboticadesalon
# FahadMu39363740
# X3UeNlqkXHLDhNj
# Atif_252
# SallyMiao3
# SamuelOpiny1
# ElvisArinaitwe
# DamnedHiker
# i__miljan
# FredericRoland7
# pmeisl
# Mbuijames
# DRR_tweet546
# ouznoreyi
# Abhishe41381252
# Jumar_Alam
# velasquezerik
# somepythonista
# KelvinTech_
# technorca
# vvvenkatesh748
# HamedMsq
# lordfarshad
# stets_10
# NgocCao16
# RotiAyub
# RBalwane
# riffadi09
# HieuProgrammer
# Assassin__Sayan
# Mdmohiuddinakib
# ghassent
# joelmarinho2016
# DuyetTran0811
# linx331
# diemesleno
# mrDanielfo
# theforgiversign
# Bullmcabe
# fatematzuhora
# JordanGundy
# ShohruhK94
# marlysson10
# harismubashir1
# CallumAndCS
# pinoyscreencast
# mumobrian3
# elisee_djapa
# ayazamlani
# Olaiw0la
# Djembeleza
# Laba_N
# beankind
# jamshaidsohail5
# Aniketkuma1
# AkshKamar
# SMirza87
# RaeCodes
# JTechome
# _chemoget_
# mount8848MT
# iemredemircom
# Ericb1925
# Ammary07
# weslleydocati
# Brunods1001
# WUrf7Ac3j6GaFLK
# tavissiva
# TSgt_Green
# PredragPrica
# brianweber21
# sananand007
# samuel6979
# justahmed99_
# killerbaby122
# bahmanshams
# marcusmuasa
# itsMeAmin
# Heenashree
# Dogabel2
# tanishjain5555
# cristia59690554
# ILYA33357849
# ITsimpiris
# fredricksimi
# Mohamma99991411
# Emigro_BlakeS
# tanabotawasshoi
# akjsal
# anykate
# Alexis_Diaz_G
# ShakerHussien4
# init_05
# robwurth
# py_bear
# metaveirass
# zealsathish
# dbrownski81
# satyam_soni1306
# iiaCinch
# devredisibirak
# ChrsJCrwly
# bgarcial
# EndlessLoop0
# himanshu_kushwa
# Laks02055041
# sdlfkorg
# sethunarayanan
# ksutariya
# michaelraeford
# EmadGKamel
# Flexmonster
# SikesDeveloper
# Alex71087215
# Shivipmp
# lpdefreitas
# Stella_thuthuy
# IsmDomCas
# sanwarul_islam
# ed_igwe
# AnandSwaraj5
# _brnms
# DRXDesign
# AvirupAditya
# picanheiro
# DeepaDeepak12
# jcmartinez96
# ziadnov
# tvvit_ter
# SergeyIbragimov
# GuiguiLet
# IslamMadkour3
# CannonJimmye
# vanthough
# mahmoudreda199
# twisbrogan
# NiranSinghLodhi
# deltahedge1
# JohnFinchPhoto
# yuturok
# jlamigueiro
# Hasti_paliwal
# thebrogadget1
# arbazkhan971
# Shivang70585770
# getnatiman
# rameshkambadas
# alilosoft
# trinity11726
# SoSoubhagya
# MaiQ1988
# KensiNamara
# devdap1
# kimseunghyun76
# camcasc
# PeriTravel
# TomR4vn
# JoeMancusoDev
# vijaya_chander
